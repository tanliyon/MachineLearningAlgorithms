# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Hyperparameters & Constants
FILEPATH = 'E:\Projects\TensorFlowPlayground\CIFAR10\cifar-10-python\cifar-10-batches-py'
CONFIDENCE_MARGIN = 1
STEP_SIZE = 0.01
REGULARIZATION_WEIGHT = 0.01
BATCH_SIZE = 128
EPOCH = 200

# %%
def unpickle(file):
    import pickle
    with open(file, 'rb') as fo:
        dict = pickle.load(fo, encoding='bytes')
        features = dict[b'data']
        target = dict[b'labels']
    return features, target

# %%
class mutliclassSVM:
    
    def __init__(self, W, regularization="L1", polyDegree=3, lossMethod="SVMLoss", epoch=5, 
                 maxIter=1000, margin=1, alpha=0.001, beta=0.001):
        self.W = W
        self.regularization = regularization
        self.polyDegree = polyDegree
        self.lossMethod = lossMethod
        self.margin = margin
        self.epoch = epoch
        self.alpha = alpha
        self.beta=beta
        return;
    
    def fit(self, xTrain, yTrain, xTest, yTest, numberOfBatches):
        loss = []
        acc = []
        batchSize = int(numberOfInputs/numberOfBatches)
        gradient = self.evalGradient(xTrain, yTrain)
        for i in range(self.epoch):
            # Step size scheduling
            #if (i == 100):
             #   self.alpha = self.alpha/2
            #if (i == 150):
             #   self.alpha = self.alpha/2
            loss.append(self.SVMLoss(xTrain, yTrain, "sum", self.margin))
            acc.append(self.accuracy(xTest, yTest, xTest.shape[0]))
            print("Iter: %03d, Loss: %.3f, Accuracy: %.3f" % (i+1, loss[i], acc[i]))
            gradient += self.adaGrad(xTrain, yTrain, gradient)
            #self.vanillaGD(xTrain, yTrain)
        return loss, acc
        
    def SVMLoss(self, xTrain, yTrain, method, margin):
        yPredict = np.matmul(xTrain, self.W)
        loss = np.maximum(0, yPredict - yTrain + self.margin)
        loss[yTrain>0] = 0
        if (method == "sum"):       
            loss = loss.sum()
            loss /= (numberOfInputs*(numberOfOutputs-1))
            return loss
        if (method == "matrix"):
            loss[yTrain>0] = -np.maximum(0, yTrain[yTrain>0]-yPredict[yTrain>0]+self.margin) 
            return loss
    
    def vanillaGD(self, xTrain, yTrain):
        gradientMatrix = self.evalGradient(xTrain, yTrain)
        self.W -= self.alpha*gradientMatrix
        return 
    
    def adaGrad(self, xTrain, yTrain, previousGradient):
        gradientMatrix = self.evalGradient(xTrain, yTrain)
        rate = 0.00002
        self.W -= (self.alpha/np.sqrt(rate*np.mean(previousGradient**2) + 1*10**-8))*gradientMatrix
        return gradientMatrix
    
    def evalGradient(self, xTrain, yTrain):
        lossMatrix = self.SVMLoss(xTrain, yTrain, "matrix", self.margin)
        gradientMatrix = np.matmul(np.transpose(xTrain), lossMatrix)
        gradientMatrix /= numberOfInputs
        return gradientMatrix
    
    def accuracy(self, xTest, yTest, batchSize):
        yPredict = np.matmul(xTest, self.W)
        count = 0
        for i in range (batchSize):
            if (np.argmax(yPredict[i]) == np.argmax(yTest[i])):
                count += 1
        accuracy = (count / batchSize) * 100
        return accuracy

# %%
# Import training and testing set
xTrain1, yTrain1 = unpickle(FILEPATH+'\\data_batch_1')
xTrain2, yTrain2 = unpickle(FILEPATH+'\\data_batch_2')
xTrain3, yTrain3 = unpickle(FILEPATH+'\\data_batch_3')
xTrain4, yTrain4 = unpickle(FILEPATH+'\\data_batch_4')
xTrain5, yTrain5 = unpickle(FILEPATH+'\\data_batch_5')
xTrain = np.concatenate((xTrain1, xTrain2, xTrain3, xTrain4, xTrain5))
yTrain = np.concatenate((yTrain1, yTrain2, yTrain3, yTrain4, yTrain5))
xTest, yTest = unpickle(FILEPATH+'\\test_batch')

# %%
# Normalization
xTrain = xTrain / 255
xTest = xTest / 255
xTrain.shape
numberOfInputs = xTrain.shape[0]
numberOfOutputs = 10

# %%
yTrainEncoded = np.zeros((numberOfInputs, len(np.unique(yTrain))))
for i in range(numberOfInputs):
    yTrainEncoded[i][yTrain[i]-1] = 1

yTestEncoded = np.zeros((xTest.shape[0], len(np.unique(yTest))))
for i in range(xTest.shape[0]):
    yTestEncoded[i][yTest[i]-1] = 1

# %%
# Initialize weights and bias
W = (np.random.rand(3072, 10))

# %%
SVM = mutliclassSVM(W, polyDegree=2, margin=CONFIDENCE_MARGIN, alpha=STEP_SIZE, beta = REGULARIZATION_WEIGHT, epoch=EPOCH)
loss, accuracy = SVM.fit(xTrain, yTrainEncoded, xTest, yTestEncoded, BATCH_SIZE)

fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(10, 4))
ax[0].plot(np.arange(EPOCH), loss)
ax[0].set_title("Loss vs Epoch")
ax[0].set_xlabel("Epoch")
ax[0].set_ylabel("SVM Loss")
ax[1].plot(np.arange(EPOCH), accuracy)
ax[1].set_title("Accuracy vs Epoch")
ax[1].set_xlabel("Epoch")
ax[1].set_ylabel("Accuracy")
plt.show()
# Out:
# Iter: 001, Loss: 727.629, Accuracy: 10.000
# Iter: 002, Loss: 0.000, Accuracy: 10.000
# Iter: 003, Loss: 0.000, Accuracy: 10.000
# Iter: 004, Loss: 0.000, Accuracy: 10.000
# Iter: 005, Loss: 0.000, Accuracy: 10.000
# Iter: 006, Loss: 0.000, Accuracy: 10.050
# Iter: 007, Loss: 0.008, Accuracy: 10.960
# Iter: 008, Loss: 0.204, Accuracy: 14.150
# Iter: 009, Loss: 0.839, Accuracy: 20.700
# Iter: 010, Loss: 1.864, Accuracy: 25.770
# Iter: 011, Loss: 2.704, Accuracy: 27.600
# Iter: 012, Loss: 2.951, Accuracy: 28.350
# Iter: 013, Loss: 2.936, Accuracy: 28.560
# Iter: 014, Loss: 2.868, Accuracy: 28.740
# Iter: 015, Loss: 2.797, Accuracy: 28.980
# Iter: 016, Loss: 2.728, Accuracy: 29.130
# Iter: 017, Loss: 2.661, Accuracy: 29.290
# Iter: 018, Loss: 2.597, Accuracy: 29.390
# Iter: 019, Loss: 2.535, Accuracy: 29.450
# Iter: 020, Loss: 2.475, Accuracy: 29.570
# Iter: 021, Loss: 2.417, Accuracy: 29.730
# Iter: 022, Loss: 2.361, Accuracy: 29.820
# Iter: 023, Loss: 2.307, Accuracy: 30.030
# ...

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(10, 4))
ax[0].plot(np.arange(EPOCH), loss)
ax[0].set_title("Loss vs Epoch")
ax[0].set_xlabel("Epoch")
ax[0].set_ylabel("SVM Loss")
ax[1].plot(np.arange(EPOCH), accuracy)
ax[1].set_title("Accuracy vs Epoch")
ax[1].set_xlabel("Epoch")
ax[1].set_ylabel("Accuracy")
plt.show()
